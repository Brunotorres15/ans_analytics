# %%
# %sql

CREATE OR REPLACE TABLE dev.gold.DIM_CONTRATACAO
LOCATION "s3://novadrive-project/gold/dim_contratacao"
AS
SELECT 
  monotonically_increasing_id() AS SK_CONTRATACAO,
  CONTRATACAO AS NM_CONTRATACAO
FROM (
  SELECT DISTINCT CONTRATACAO FROM dev.silver.silver_sip
);
