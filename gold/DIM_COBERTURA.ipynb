# %%
# %sql

CREATE OR REPLACE TABLE dev.gold.DIM_COBERTURA
LOCATION "s3://novadrive-project/gold/dim_cobertura"
AS
SELECT 
  monotonically_increasing_id() AS SK_COBERTURA,
  COBERTURA AS NM_COBERTURA
FROM (
  SELECT DISTINCT COBERTURA FROM dev.silver.silver_sip
);
