# %%
# %run ../lib/ingestion_functions

# %%
delta_table_name = "fato_mapa_assistencial"

# %%
target_path = f"s3://novadrive-project/gold/{delta_table_name}"
checkpoint_location = f"s3://novadrive-project/metastore/gold/{delta_table_name}_chk"

# %%
gold_ingestor = GoldIngestor(
    spark=spark,
    source_table="silver_sip",
    catalog="dev",
    source_schema="silver",
    target_schema="gold",
    gold_table="fato_mapa_assistencial",
    target_path=target_path,
    checkpoint_path=checkpoint_location
)

gold_ingestor.execute()
